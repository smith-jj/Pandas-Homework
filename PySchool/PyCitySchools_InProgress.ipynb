# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# School File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"


# Read School Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
school_data.columns
# Out:
# Index(['School ID', 'school_name', 'type', 'size', 'budget'], dtype='object')

# %%
school_data.columns = ['School_ID', 'School_Name', 'School_Type', 'School_Size', 'School_Budget']

# %%
school_data.columns
# Out:
# Index(['School_ID', 'School_Name', 'School_Type', 'School_Size',
#        'School_Budget'],
#       dtype='object')

# %%
school_data.head()
# Out:
#    School_ID            School_Name School_Type  School_Size  School_Budget
# 0          0      Huang High School    District         2917        1910635
# 1          1   Figueroa High School    District         2949        1884411
# 2          2    Shelton High School     Charter         1761        1056600
# 3          3  Hernandez High School    District         4635        3022020
# 4          4    Griffin High School     Charter         1468         917500

# %%
# Student File to Load (Remember to Change These)
student_data_to_load = "Resources/students_complete.csv"

# Read Student Data File and store into Pandas Data Frames
student_data = pd.read_csv(student_data_to_load)
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
student_data.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score'],
#       dtype='object')

# %%
student_data.columns = ['Student_ID', 'Student_Name', 'Gender', 'Grade', 'School_Name',
       'Reading_Score', 'Math_Score']

# %%
student_data.columns
# Out:
# Index(['Student_ID', 'Student_Name', 'Gender', 'Grade', 'School_Name',
#        'Reading_Score', 'Math_Score'],
#       dtype='object')

# %%
student_data.head()
# Out:
#    Student_ID       Student_Name Gender Grade        School_Name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    Reading_Score  Math_Score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Merge CSV files 
combined_df = pd.merge(school_data, student_data, how='outer', on='School_Name')
combined_df
# Out:
#        School_ID         School_Name School_Type  School_Size  School_Budget  \
# 0              0   Huang High School    District         2917        1910635
# 1              0   Huang High School    District         2917        1910635
# 2              0   Huang High School    District         2917        1910635
# 3              0   Huang High School    District         2917        1910635
# 4              0   Huang High School    District         2917        1910635
# 5              0   Huang High School    District         2917        1910635
# 6              0   Huang High School    District         2917        1910635
# 7              0   Huang High School    District         2917        1910635
# 8              0   Huang High School    District         2917        1910635
# 9              0   Huang High School    District         2917        1910635
# 10             0   Huang High School    District         2917        1910635
# ...

# %%
# Replace all NaN values with 0 or the new combined dataframe 
# combined_df= combined_df.fillna(0)
# combined_df.head()

# %%
# Clean School Names 
# combined_df = combined_df.loc[combined_df['School_Name'] != "?"]
# combined_df.head()

# %%
# Clean School IDs
# combined_df = combined_df.loc[combined_df['School_ID'] != "?"]
# combined_df.head()

# %%
# Clean School Types
# combined_df = combined_df.loc[combined_df['School_Type'] != "?"]
# combined_df.head()

# %%
# Check Clean data 
combined_df.describe()
# Out:
#           School_ID   School_Size  School_Budget    Student_ID  Reading_Score  \
# count  39170.000000  39170.000000   3.917000e+04  39170.000000    39170.00000
# mean       6.978172   3332.957110   2.117241e+06  19584.500000       81.87784
# std        4.444329   1323.914069   8.749987e+05  11307.549359       10.23958
# min        0.000000    427.000000   2.480870e+05      0.000000       63.00000
# 25%        3.000000   1858.000000   1.081356e+06   9792.250000       73.00000
# 50%        7.000000   2949.000000   1.910635e+06  19584.500000       82.00000
# 75%       11.000000   4635.000000   3.022020e+06  29376.750000       91.00000
# max       14.000000   4976.000000   3.124928e+06  39169.000000       99.00000
#
#          Math_Score
# count  39170.000000
# mean      78.985371
# std       12.309968
# min       55.000000
# 25%       69.000000
# 50%       79.000000
# 75%       89.000000
# max       99.000000

# %%
# District Summary


    # Calculate the total budget

    # Calculate the average math score

    # Calculate the average reading score

    # Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2

    # Calculate the percentage of students with a passing math score (70 or greater)

    # Calculate the percentage of students with a passing reading score (70 or greater)

    # Create a dataframe to hold the above results

        # Optional: give the displayed data cleaner formatting

# %%
# Groupby school names 
schools_df = combined_df.groupby("School_Name")
schools_df.head()
# Out:
#        School_ID            School_Name School_Type  School_Size  \
# 0              0      Huang High School    District         2917
# 1              0      Huang High School    District         2917
# 2              0      Huang High School    District         2917
# 3              0      Huang High School    District         2917
# 4              0      Huang High School    District         2917
# 2917           1   Figueroa High School    District         2949
# 2918           1   Figueroa High School    District         2949
# 2919           1   Figueroa High School    District         2949
# 2920           1   Figueroa High School    District         2949
# 2921           1   Figueroa High School    District         2949
# 5866           2    Shelton High School     Charter         1761
# 5867           2    Shelton High School     Charter         1761
# 5868           2    Shelton High School     Charter         1761
# ...

# %%
 # Calculate the total number of schools
schools_count = schools_df['School_ID'].count()
schools_count
# Out:
# School_Name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: School_ID, dtype: int64

# %%
schools_count.describe()
# Out:
# count      15.000000
# mean     2611.333333
# std      1420.915282
# min       427.000000
# 25%      1698.000000
# 50%      2283.000000
# 75%      3474.000000
# max      4976.000000
# Name: School_ID, dtype: float64

# %%
# Calculate the total number of students
student_totals = schools_df("School_ID")["School_size"].count()
student_totals
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-5095d6c2263b> in <module>
#       1 # Calculate the total number of students
# ----> 2 student_totals = schools_df("School_ID")["School_size"].count()
#       3 student_totals
#
# TypeError: 'DataFrameGroupBy' object is not callable
